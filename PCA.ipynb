# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.random.normal(0.0,3.5,501)

y = np.random.normal(0.0,0.5,501)

theta = -(np.pi/6.0)
x2 = x*np.cos(theta) + y*np.sin(theta)
y2 = y*np.cos(theta) - x*np.sin(theta)

# %%
plt.figure(figsize=(12,7))
plt.scatter(x2,y2)
plt.quiver(np.mean(x2),np.mean(y2),vector[0][0],vector[0][1], angles ='xy',scale=5.0, color='r')
plt.quiver(np.mean(x2),np.mean(y2),vector[0][1],vector[0][0], angles ='xy',scale=5.0, color='r')

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
pca.fit(np.c_[x2,y2])
# Out:
# PCA(copy=True, n_components=2, whiten=False)

# %%
vector = pca.components_
vector
# Out:
# array([[ 0.87242409,  0.48874964],
#        [ 0.48874964, -0.87242409]])

# %%
plt.figure(figsize=(12,7))
plt.scatter(x2,y2)
plt.quiver(np.mean(x2),np.mean(y2),vector[0][0],vector[0][1], angles ='xy',scale=5.0, color='r')
plt.quiver(np.mean(x2),np.mean(y2),vector[0][1],vector[0][0], angles ='xy',scale=5.0, color='r')

# %%
pca.explained_variance_ratio_
# Out:
# array([ 0.98116478,  0.01883522])

# %%
pca.get_covariance()
# Out:
# array([[ 10.72761158,   5.8591553 ],
#        [  5.8591553 ,   3.55136514]])

# %%
X = pca.transform(np.c_[x2,y2])

# %%
plt.scatter(X.T[0],X.T[1])
plt.axis('scaled')
# Out:
# (-15.0, 15.0, -2.0, 2.0)

# %%
pca.fit_transform(np.c_[x2,y2])
# Out:
# array([[ -6.66641961e-01,   5.06430582e-01],
#        [ -2.63539853e-01,  -2.85528848e-03],
#        [ -4.53878856e+00,   5.98561629e-01],
#        ...,
#        [  2.95843291e+00,   2.86871922e-01],
#        [  1.48435239e+00,  -3.17954847e-01],
#        [  3.54123911e+00,  -6.78140787e-02]])
