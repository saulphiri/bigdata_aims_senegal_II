# %%
from sklearn.datasets import load_iris
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline

# %%
iris = load_iris()

# %%
iris.keys()
# Out:
# ['target_names', 'data', 'target', 'DESCR', 'feature_names']

# %%
from sklearn import svm

# %%
svmp = svm.LinearSVC()
X = iris.data[(iris.target==0)|(iris.target==1),0:3:2]
y = iris.target[(iris.target==0)|(iris.target==1)]
#from sklearn import BaggingClassifier,RandomForestClassifier

# %%
plt.scatter(X.T[0],X.T[1],c=y)

# %%
X.shape
# Out:
# (100, 2)

# %%
from sklearn.preprocessing import scale
svmp = linearSVC

# %%
svmp.fit(X,y)
# Out:
# LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#      verbose=0)

# %%
svmp.predict([8.0,2.0])
# Out:
# /usr/local/lib/python2.7/dist-packages/sklearn/utils/validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# array([0])

# %%
xx,yy = np.meshgrid(np.linspace(0.0,10.0,201),np.linspace(0.0,10.0,201))

pred = svmp.predict(np.c_[xx.ravel(),yy.ravel()])
Z_svmp = pred.reshape(np.shape(xx))

plt.figure(figsize=(14,7))

plt.subplot(121)
plt.contourf(xx,yy,Z_svmp,alpha=0.4)
plt.scatter(X.T[0],X.T[1],c=y)
plt.axis('scaled')
plt.xlabel('Sepal Length')
plt.ylabel('Petal Length')
plt.title('svm',fontsize=20)
plt.xlim(4.0,8.0)
plt.ylim(0.0,5.5)
# Out:
# (0.0, 5.5)
